# %%
import pandas as pd
import numpy as np
from linearmodels import PanelOLS

import multiprocessing as mp
import multiprocessing.dummy as mpd

from scipy.optimize import newton_krylov, anderson, broyden1, broyden2

# %% [markdown]
# # Read in data
#
# Here I read in data. The important variables are:
# - `exporter`, `importer`, `industry`: These ones are self explanatory -- correspond to $i, j, k$, respectively
# - `exports`: Also self explanatory, corresponds to $x_{ij}^k$
# - `ipr`: This is equivalent to $1-\pi_{ii}^k$ from the paper
# - `Gro_PPP_SO_97`: Producer price index based on gross output -- the inverse of this is $\tilde{z}_{i}^k$
# - `rdexpend`: R&D expenditures
#
# So I will create these new variables:
# - `z` (equal to $\ln(\tilde{z}_{i}^k)$)
# - `x1` (equal to $ln({x}_{ij}^k)$)
# - `x` (equal to $\ln(\tilde{x}_{ij}^k)$)
# - `d_ij`: importer-exporter fixed effects ($\delta_{ij}$)
# - `d_jk`: importer-industry fixed effects ($\delta_{jk}$)
# - `rd`: log of R&D expenditures

# %%
data = pd.read_stata('cdk2010.dta')
data['year'] = 1997
data = data.set_index(['exporter', 'year'], drop = False)

# Add 1 to exports bc of log
data['exports'] = data['exports'] + 1

# %%
data['x1'] = np.log(data['exports'])
data['x'] = data['x1'] - np.log(1-data['ipr']/100)
data['z'] = -np.log(data['Gro_PPP_SO_97'])

data['d_ij'] = data['exporter'] + '_' + data['importer']
data['d_jk'] = data['importer'] + '_' + data['industry']

data['rd'] = np.log(data['rdexpend'])
# Out:
# /bbkinghome/tadej/miniconda3/envs/main/lib/python3.7/site-packages/pandas/core/series.py:853: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %% [markdown]
# # OLS

# %%
PanelOLS(dependent = data['x'], exog = data['z'], other_effects = data[['d_ij', 'd_jk']]).fit()
# Out:
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:                      x   R-squared:                        0.0241
# Estimator:                   PanelOLS   R-squared (Between):             -0.2215
# No. Observations:                5733   R-squared (Within):               0.0000
# Date:                Wed, Oct 16 2019   R-squared (Overall):             -0.2145
# Time:                        23:39:18   Log-likelihood                -1.096e+04
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      124.03
# Entities:                          21   P-value                           0.0000
# Avg Obs:                       273.00   Distribution:                  F(1,5019)
# Min Obs:                       273.00
# Max Obs:                       273.00   F-statistic (robust):             124.03
#                                         P-value                           0.0000
# Time periods:                       1   Distribution:                  F(1,5019)
# Avg Obs:                       5733.0
# Min Obs:                       5733.0
# Max Obs:                       5733.0
#
#                              Parameter Estimates
# ==============================================================================
#             Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------
# z              1.3708     0.1231     11.137     0.0000      1.1295      1.6121
# ==============================================================================
#
# F-test for Poolability: 27.273
# P-value: 0.0000
# Distribution: F(712,5019)
#
# Included effects: Other Effect (d_ij), Other Effect (d_jk)
# Model includes 5 other effects
# Other Effect Observations per group (d_ij):
# Avg Obs: 13.000, Min Obs: 13.000, Max Obs: 13.000, Groups: 441
# Other Effect Observations per group (d_jk):
# Avg Obs: 21.000, Min Obs: 21.000, Max Obs: 21.000, Groups: 273
# PanelEffectsResults, id: 0x7f3dfe0f1208

# %%
PanelOLS(dependent = data['x1'], exog = data['z'], other_effects = data[['d_ij', 'd_jk']]).fit()
# Out:
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:                     x1   R-squared:                        0.0311
# Estimator:                   PanelOLS   R-squared (Between):             -0.2731
# No. Observations:                5733   R-squared (Within):               0.0000
# Date:                Wed, Oct 16 2019   R-squared (Overall):             -0.2642
# Time:                        23:39:18   Log-likelihood                -1.099e+04
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      161.14
# Entities:                          21   P-value                           0.0000
# Avg Obs:                       273.00   Distribution:                  F(1,5019)
# Min Obs:                       273.00
# Max Obs:                       273.00   F-statistic (robust):             161.14
#                                         P-value                           0.0000
# Time periods:                       1   Distribution:                  F(1,5019)
# Avg Obs:                       5733.0
# Min Obs:                       5733.0
# Max Obs:                       5733.0
#
#                              Parameter Estimates
# ==============================================================================
#             Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------
# z              1.5730     0.1239     12.694     0.0000      1.3300      1.8159
# ==============================================================================
#
# F-test for Poolability: 24.948
# P-value: 0.0000
# Distribution: F(712,5019)
#
# Included effects: Other Effect (d_ij), Other Effect (d_jk)
# Model includes 5 other effects
# Other Effect Observations per group (d_ij):
# Avg Obs: 13.000, Min Obs: 13.000, Max Obs: 13.000, Groups: 441
# Other Effect Observations per group (d_jk):
# Avg Obs: 21.000, Min Obs: 21.000, Max Obs: 21.000, Groups: 273
# PanelEffectsResults, id: 0x7f3dfbf1a4a8

# %% [markdown]
# # IV
#
# Unfortunately I have to do IV in stata, as only it can drop some annoying variables. Below is the code I use to construct the variables and run the regressions
#
# ```
# use cdk2010
#
# gen z = -ln(Gro_PPP_SO_97)
#
# gen x1 = ln(exports)
# replace ipr = ipr/100
# gen x = x1 - ln(1-ipr)
# gen rd = log(rdexpend)
#
# gen d_ij = importer + "_" + exporter
# gen d_jk = importer + "_" + industry
#
# ivreghdfe x (z=rd), absorb(d_ij d_jk)
# ivreghdfe x1 (z=rd), absorb(d_ij d_jk)
# ```
#
# Bellow you can find the output for the last 2 commands

# %% [markdown]
# ```
# IV (2SLS) estimation
# --------------------
#
# Estimates efficient for homoskedasticity only
# Statistics consistent for homoskedasticity only
#
#                                                       Number of obs =     5649
#                                                       F(  1,  4955) =    44.95
#                                                       Prob > F      =   0.0000
# Total (centered) SS     =   14677.7366                Centered R2   =  -0.2364
# Total (uncentered) SS   =   14677.7366                Uncentered R2 =  -0.2364
# Residual SS             =  18147.03231                Root MSE      =    1.914
#
# ------------------------------------------------------------------------------
#            x |      Coef.   Std. Err.      t    P>|t|     [95% Conf. Interval]
# -------------+----------------------------------------------------------------
#            z |   5.814509   .8672592     6.70   0.000     4.114297    7.514722
# ------------------------------------------------------------------------------
# Underidentification test (Anderson canon. corr. LM statistic):         138.034
#                                                    Chi-sq(1) P-val =    0.0000
# ------------------------------------------------------------------------------
# Weak identification test (Cragg-Donald Wald F statistic):              124.109
# Stock-Yogo weak ID test critical values: 10% maximal IV size             16.38
#                                          15% maximal IV size              8.96
#                                          20% maximal IV size              6.66
#                                          25% maximal IV size              5.53
# Source: Stock-Yogo (2005).  Reproduced by permission.
# ------------------------------------------------------------------------------
# Sargan statistic (overidentification test of all instruments):           0.000
#                                                  (equation exactly identified)
# ------------------------------------------------------------------------------
# Instrumented:         z
# Excluded instruments: rd
# Partialled-out:       _cons
#                       nb: total SS, model F and R2s are after partialling-out;
#                           any small-sample adjustments include partialled-out
#                           variables in regressor count K
# ------------------------------------------------------------------------------
#
# Absorbed degrees of freedom:
# -----------------------------------------------------+
#  Absorbed FE | Categories  - Redundant  = Num. Coefs |
# -------------+---------------------------------------|
#         d_ij |       441           0         441     |
#         d_jk |       273          21         252     |
# -----------------------------------------------------+
#
# ```

# %% [markdown]
# # Shock effect estimation

# %%
data = data.reset_index(drop = True)
t = 6

# Get all countries and industries
countries = data['exporter'].unique()
industries = data['industry'].unique()

# Calculate income, total exports and total consumption in sector
exports = data.groupby(['exporter', 'importer', 'industry'])['exports'].sum()
consumption = exports.groupby(['importer', 'industry']).sum()
GDP = exports.groupby(['importer']).sum()

# World trade imbalance
imbalance = (exports.groupby(['exporter']).sum() - GDP)/GDP.sum()

# Obtain import shares
pi = (exports/consumption).reorder_levels([2,0,1])

# Obtain expenditure shapres
alpha = consumption/GDP

# %%
# Reindex for easier calculations later
GDP.index = GDP.index.rename('exporter')
consumption.index = consumption.index.rename(['exporter', 'industry'])

# %%
# Changes (hat w just the provisional first guess)
hat_d = pd.Series(1, index = exports.index)
hat_w = pd.Series(1.0, index = GDP.index)
hat_z = pd.Series(1.0, index = consumption.index)

# 80% productivity increase in Japan
hat_z['JPN'] = 1.8

# %%
cnt_dict = {}
for i, cnt in enumerate(countries):
    cnt_dict[cnt] = i

# Calculates the denominator in equation (1)
def denominator(j, k, hat_w, hat_d, hat_z, pi, t):
    
    # We're looping over exporters, so column will be 'exporter'
    pi_t = pi[:, j, k]
    hat_d_t = hat_d[:, j, k] 
    hat_z_t = hat_z[:, k]
    
    return (pi_t * np.power(hat_w * hat_d_t / hat_z_t, -t)).sum()

# Calculates the item inside the sum
def sum_item(i, j, k, hat_w, hat_d, hat_z, pi, GDP, alpha, t):
    
    upper = pi[i, j, k] * np.power(hat_w[cnt_dict[i]] * hat_d[i, j, k] / hat_z[i, k], -t)
    lower = denominator(j, k, hat_w, hat_d, hat_z, pi, t)
    right = alpha[j, k] * hat_w[cnt_dict[j]] * GDP[j]

    return (upper/lower) * right

# Calculates the LHS of the equation
def LHS(i, hat_w, hat_d, hat_z, pi, GDP, alpha, t):
    s = 0
    
    for j in countries:
        for k in industries:
            s += sum_item(i, j, k, hat_w, hat_d, hat_z, pi, GDP, alpha, t)
            
    return s

#Calculates the RHS of the equation
def RHS(i, hat_w, GDP, imbalance):
    return hat_w[cnt_dict[i]] * GDP[i] + imbalance[i] * (hat_w*GDP).sum()

def R(args):
    i = args[0]
    hat_w = args[1]
    
    return LHS(i, hat_w, hat_d, hat_z, pi, GDP, alpha, t) - RHS(i, hat_w, GDP, imbalance)

loopy = [(i, hat_w) for i in countries]

# The function for the optimizer
def F(hat_w):
    
    with mp.Pool(mp.cpu_count()) as pool:
        r = np.array(pool.map(R, loopy))/GDP.sum()
    
    print(np.absolute(r).sum(), hat_w.max(), hat_w.min())
    return r

# %%
F(hat_w).round(2)
# Out:
# 0.5742202907471308 1.0 1.0
# array([-0.01, -0.01, -0.  , -0.  , -0.01, -0.  , -0.02, -0.04, -0.  ,
#        -0.  , -0.  , -0.02,  0.29, -0.02, -0.01, -0.  , -0.  , -0.  ,
#        -0.  , -0.02, -0.12])

# %%
k = anderson(F, hat_w)
# Out:
# 0.5742202907471308 1.0 1.0
# 0.5742202907471308 3.0843854933804598 0.16116898098872567
# 0.5742202907471308 2.0421927466902297 0.5805844904943629
# 0.5742202907471308 1.44048248384115 0.8227341478097465
# 0.5742202907471308 1.220241241920575 0.9113670739048733
# 0.5742202907471308 1.1101206209602876 0.9556835369524366
# 0.5742202907471308 1.0550603104801437 0.9778417684762183
# 0.5742202907471308 1.027530155240072 0.9889208842381092
# 0.5742202907471308 1.013765077620036 0.9944604421190546
# 0.5742202907471308 3.0843854933804598 0.16116898098872567
# 0.5742202907471308 5.1687709867609195 -0.6776620380225487
# 0.5742202907471308 4.12657824007069 -0.2582465285169115
# 0.5742202907471308 3.52486797722161 -0.016096871201527807
# 0.5742202907471308 3.304626735301035 0.07253605489359893
# 0.5742202907471308 3.194506114340747 0.1168525179411623
# 0.5742202907471308 3.1394458038606037 0.139010749464944
# 0.5742202907471308 3.1119156486205317 0.15008986522683482
# 0.5742202907471308 3.0981505710004957 0.15562942310778025
# 0.5742202907471308 5.1687709867609195 -0.6776620380225487
# 0.5742202907471308 7.25315648014138 -1.516493057033823
# 0.5742202907471308 6.210963733451149 -1.0970775475281858
# 0.5742202907471308 5.60925347060207 -0.8549278902128021
# 0.5742202907471308 5.389012228681494 -0.7662949641176754
# 0.5742202907471308 5.278891607721207 -0.7219785010701121
# 0.5742202907471308 5.223831297241063 -0.6998202695463304
# 0.5742202907471308 5.1963011420009915 -0.6887411537844395
# 0.5742202907471308 5.1825360643809555 -0.683201595903494
# 0.5742202907471308 7.25315648014138 -1.516493057033823
# 0.5742202907471308 9.337541973521839 -2.3553240760450973
# 0.5742202907471308 8.29534922683161 -1.9359085665394602
# 0.5742202907471308 7.69363896398253 -1.6937589092240766
# 0.5742202907471308 7.4733977220619545 -1.60512598312895
# 0.5742202907471308 7.3632771011016676 -1.5608095200813865
# 0.5742202907471308 7.308216790621524 -1.5386512885576047
# 0.5742202907471308 7.280686635381452 -1.527572172795714
# 0.5742202907471308 7.266921557761416 -1.5220326149147685
# 0.5742202907471308 9.337541973521839 -2.3553240760450973
# 0.5742202907471308 11.421927466902298 -3.1941550950563715
# 0.5742202907471308 10.379734720212069 -2.7747395855507344
# 0.5742202907471308 9.778024457362989 -2.5325899282353506
# 0.5742202907471308 9.557783215442415 -2.443957002140224
# 0.5742202907471308 9.447662594482127 -2.3996405390926605
# 0.5742202907471308 9.392602284001983 -2.377482307568879
# 0.5742202907471308 9.365072128761911 -2.366403191806988
# 0.5742202907471308 9.351307051141875 -2.360863633926043
# 0.5742202907471308 11.421927466902298 -3.1941550950563715
# 0.5742202907471308 13.506312960282758 -4.032986114067646
# 0.5742202907471308 12.464120213592528 -3.6135706045620086
# 0.5742202907471308 11.862409950743448 -3.3714209472466248
# 0.5742202907471308 11.642168708822874 -3.2827880211514984
# 0.5742202907471308 11.532048087862586 -3.2384715581039347
# 0.5742202907471308 11.476987777382442 -3.216313326580153
# 0.5742202907471308 11.44945762214237 -3.2052342108182623
# 0.5742202907471308 11.435692544522334 -3.199694652937317
# 0.5742202907471308 13.506312960282758 -4.032986114067646
# 0.5742202907471308 15.590698453663217 -4.87181713307892
# 0.5742202907471308 14.548505706972987 -4.452401623573284
# 0.5742202907471308 13.946795444123907 -4.2102519662579
# 0.5742202907471308 13.726554202203333 -4.121619040162773
# 0.5742202907471308 13.616433581243045 -4.077302577115209
# 0.5742202907471308 13.561373270762902 -4.055144345591428
